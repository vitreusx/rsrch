# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rsrch.rl.dqn import dqn
dqn()
# Out:
# [val] step=0, ep=0, mean=9.56, std=0.79, min=8.00, max=11.00
# [val] step=1000, ep=67, mean=9.75, std=1.06, min=8.00, max=12.00
# [val] step=2000, ep=152, mean=19.41, std=2.38, min=15.00, max=24.00
# [val] step=3000, ep=173, mean=133.72, std=18.71, min=101.00, max=169.00
# [val] step=4000, ep=181, mean=161.47, std=45.99, min=100.00, max=334.00
# [val] step=5000, ep=186, mean=162.50, std=49.15, min=103.00, max=313.00
# [val] step=6000, ep=191, mean=190.81, std=48.55, min=127.00, max=308.00
# [val] step=7000, ep=196, mean=182.22, std=34.26, min=144.00, max=305.00
# [val] step=8000, ep=202, mean=173.41, std=48.08, min=106.00, max=345.00
# [val] step=9000, ep=210, mean=142.28, std=20.12, min=116.00, max=192.00
# [val] step=10000, ep=218, mean=137.47, std=14.77, min=116.00, max=172.00
# [val] step=11000, ep=225, mean=131.25, std=9.48, min=114.00, max=153.00
# [val] step=12000, ep=233, mean=137.06, std=12.30, min=119.00, max=163.00
# ...
